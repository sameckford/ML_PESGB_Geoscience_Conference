# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import copy as cp
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
# Import well tops dataframe, columns should be the format - ['Well_Name', 'Surface', 'X', 'Y', 'Z', 'MD', 'TWT_Picked', 'Z_depth', 'Vint', 'TWT_Auto']
tops_columns = ['Well_Name', 'Surface', 'X', 'Y', 'Z', 'MD', 'TWT_Picked', 'Z_depth', 'Vint', 'TWT_Auto']
headers = [i.strip() for i in open("Well_Tops").readlines()[5:33]]
well_master_df = pd.read_csv("Well_Tops", delim_whitespace=True, skiprows =34, names=headers)

WELL_TEST = ["22/9-4", "23/21a-8","23/21-5","22/15-3","23/21-6","22/10b-6","22/10a-4", "23/11-2","22/14b-6X","22/14b-6U",
             "23/6-1","22/14b-6W","22/14b-9", "22/14b-6V","22/14b-6S", "22/15-4", "22/14b-6T","22/14b-9Z","22/14b-6Q",
             "23/16b-9","23/16f-11","22/14b-8","23/21-7Z","22/14b-6Y","22/19b-4","23/16f-12","23/21-7","22/13b-7Z","23/21-1"]

TOPS ='TWT_Auto'

# %%
well_master_df.rename(columns={"TWT auto": TOPS, "TWT picked": "TWT_Picked", "Z":"Z_depth"}, inplace=True)
well_master_df["Z_depth"] = well_master_df["Z_depth"] *-1

# %%
well_master_df[TOPS] = (well_master_df[TOPS] /1000)*-1

# %%
nunique_df = well_master_df.groupby('Surface')['X'].nunique()
well_master_df[['TWT_Picked', 'TWT_Auto']] = well_master_df[['TWT_Picked', 'TWT_Auto']] 
well_master_df["Z_depth"] = well_master_df["Z_depth"]*0.3048
well_master_df.drop(columns=["MD", "X", "Y", "TWT_Picked"], inplace=True)

# %%
well_master_df.head()
# Out:
#    Z_depth  TWT_Auto  Geological age     Type Surface      Well Interpreter  \
# 0  89.9160   0.11791            -999  Horizon  Seabed   22/19-2    jnasseri
# 1  91.7448   0.10312            -999  Horizon  Seabed   22/20-1    jnasseri
# 2  91.1352   0.12713            -999  Horizon  Seabed  22/14a-2    jnasseri
# 3  92.0496   0.11953            -999  Horizon  Seabed    22/9-4    jnasseri
# 4  89.9160   0.14256            -999  Horizon  Seabed  22/14a-7    jnasseri
#
#    Confidence factor  Dip angle  Dip azimuth     ...       Symbol  \
# 0               -999       -999         -999     ...            0
# 1               -999       -999         -999     ...            0
# 2               -999       -999         -999     ...            0
# 3               -999       -999         -999     ...            0
# 4               -999       -999         -999     ...            0
#
#    Locked to fault  FLOAT,GR_min_Ichron  FLOAT,GR_max_Ichron  Z_depth_T-1  \
# 0                0               -999.0               -999.0          0.0
# 1                0               -999.0               -999.0          0.0
# 2                0               -999.0               -999.0          0.0
# 3                0               -999.0               -999.0          0.0
# 4                0               -999.0               -999.0          0.0
#
#    TWT_Auto_T-1  isochron_auto  ischore     Vint_int  mid-point_Z
# 0           0.0       0.058955  89.9160  1525.163260      44.9580
# 1           0.0       0.051560  91.7448  1779.379364      45.8724
# 2           0.0       0.063565  91.1352  1433.732400      45.5676
# 3           0.0       0.059765  92.0496  1540.192420      46.0248
# 4           0.0       0.071280  89.9160  1261.447811      44.9580
#
# [5 rows x 30 columns]

# %%
well_master_df[["Z_depth_T-1", 'TWT_Auto_T-1']] = well_master_df.sort_values("Z_depth",ascending=True).groupby("Well")[["Z_depth",'TWT_Auto']].shift(1)

# %%
well_master_df["Z_depth_T-1"].fillna(value=0, inplace =True)
well_master_df["TWT_Auto_T-1"].fillna(value=0, inplace =True)

# %%
# well_master_df["isochron_picked"] = (well_master_df["TWT_Picked"]*0.5)-(well_master_df["TWT_Picked_T-1"]*0.5)
well_master_df["isochron_auto"] = (well_master_df["TWT_Auto"]*0.5)-(well_master_df["TWT_Auto_T-1"]*0.5)

well_master_df["ischore"] = well_master_df["Z_depth"]-well_master_df["Z_depth_T-1"]

# well_master_df["int_vel_Picked"] = well_master_df["ischore"] / well_master_df["isochron_picked"] 
well_master_df["Vint_int"] = well_master_df["ischore"] / well_master_df["isochron_auto"] 
well_master_df["Vint_int"].fillna(0, inplace=True)

# %%
well_master_df["mid-point_Z"] = (well_master_df["ischore"] /2) + well_master_df["Z_depth_T-1"]
df_train_global = well_master_df.loc[~well_master_df["Well"].isin(WELL_TEST)]
df_test_global = well_master_df.loc[well_master_df["Well"].isin(WELL_TEST)]

# %%
df_train_global
# Out:
#          Z_depth  TWT_Auto  Geological age     Type          Surface  \
# 0      89.916000   0.11791            -999  Horizon           Seabed
# 1      91.744800   0.10312            -999  Horizon           Seabed
# 2      91.135200   0.12713            -999  Horizon           Seabed
# 3      92.049600   0.11953            -999  Horizon           Seabed
# 4      89.916000   0.14256            -999  Horizon           Seabed
# 5      90.830400   0.13540            -999  Horizon           Seabed
# 6      90.220800   0.10599            -999  Horizon           Seabed
# 7      90.830400   0.10497            -999  Horizon           Seabed
# 8      91.440000   0.09567            -999  Horizon           Seabed
# 9      87.172800   0.09906            -999  Horizon           Seabed
# 10     91.741752   0.12356            -999  Horizon           Seabed
# 11     90.220800   0.13745            -999  Horizon           Seabed
# 12     91.135200   0.09070            -999  Horizon           Seabed
# 13     88.392000   0.09577            -999  Horizon           Seabed
# 14     89.641680   0.08918            -999  Horizon           Seabed
# 15     85.923120   0.12931            -999  Horizon           Seabed
# 16     91.043760   0.12728            -999  Horizon           Seabed
# 17     93.268800   0.11816            -999  Horizon           Seabed
# 18     86.868000   0.11700            -999  Horizon           Seabed
# 19     84.734400   0.11961            -999  Horizon           Seabed
# 20     87.471504   0.09066            -999  Horizon           Seabed
# 21     87.477600   0.09690            -999  Horizon           Seabed
# 22     87.782400   0.09403            -999  Horizon           Seabed
# 23     91.440000   0.11522            -999  Horizon           Seabed
# 24     90.522552   0.13448            -999  Horizon           Seabed
# 25     90.522552   0.10777            -999  Horizon           Seabed
# 26     90.522552   0.12725            -999  Horizon           Seabed
# 27     90.522552   0.11434            -999  Horizon           Seabed
# 28     90.522552   0.10883            -999  Horizon           Seabed
# 29     90.522552   0.12390            -999  Horizon           Seabed
# ..           ...       ...             ...      ...              ...
# 502  2520.766104  1953.771768  1260.383052
# 503    33.092136  2827.179496  2921.012700
# 504    82.061304  3320.303621  3004.503516
# 505     0.000000     0.000000  3884.526648
# 506    25.563576  4787.186517  3819.715500
# 507   660.376632  5147.530065  3476.745396
# 508    12.188952  4029.405620  4164.127308
# 509    36.259008  2853.916411  2890.811592
# 510    31.074360  2960.872797  2924.478276
# 511   118.195344  3220.142869  2999.113128
# 512  2863.641720  1987.011838  1431.820860
# 513    39.105840  2846.131004  2883.194640
# 514    11.445240  2784.729927  2908.470180
# 515   128.354328  3136.330556  2978.369964
# 516    47.338488  2913.137723  3066.216372
# 517    25.338024  2980.944000  2950.227780
# 518     0.576072  3113.902703  2963.184828
# 519    30.077664  2887.917811  2848.112160
# 520    57.570624  2981.389125  2919.319536
# 521   120.091200  3247.463494  3008.150448
#
# [522 rows x 30 columns]

# %%
df_dummys = pd.get_dummies(well_master_df, columns=["Surface", "Well"], prefix=["IS_SURFACE_", "IS_WELL_"])

# %%
df_final = df_dummys

# %%
df_final["Wells"] = well_master_df["Well"]
df_train = df_final.loc[~df_final.Wells.isin(WELL_TEST)]
df_test = df_final.loc[df_final.Wells.isin(WELL_TEST)]

# %%
dummy_cols = [i for i in df_final.columns if "IS_SURFACE_" in i or "IS_WELL_" in i]

# %%
def func_fitting(X_series, y_series, df, regressor = LinearRegression):
#     X_temp = np.array(df[X_series]).reshape(len(is_df_well),1)
#     y_temp = np.array(df[y_series]).reshape(len(is_df_well),1)
    
    regressor_temp = LinearRegression()
    regressor_temp.fit(df[X_series].values, df[y_series].values)
    return regressor_temp

# %%
training_cols_TWT_auto = cp.deepcopy(dummy_cols)
training_cols_TWT_auto.append('TWT_Auto')
training_cols_mid_point_Z = cp.deepcopy(dummy_cols)
training_cols_mid_point_Z.append('mid-point_Z')

# %%
regressor_t_z_depth = func_fitting(training_cols_TWT_auto, 'Z_depth', df_train)

# %%
regressor_mz_depth = func_fitting(training_cols_mid_point_Z, 'Z_depth', df_train)

# %%
regressor_mz_vint = func_fitting(training_cols_mid_point_Z, 'Vint_int', df_train)

# %%
regressor_t_vint = func_fitting(training_cols_TWT_auto, 'Vint_int', df_train)

# %%
df_test_global["pred_tz"] = regressor_t_z_depth.predict(df_test[training_cols_TWT_auto].values)
# Out:
# C:\Users\DR25798\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test_global["vint_pred"] = regressor_t_vint.predict(df_test[training_cols_TWT_auto].values)
# Out:
# C:\Users\DR25798\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_test_global
# Out:
# Empty DataFrame
# Columns: [Z_depth, TWT_Auto, Geological age, Type, Surface, Well, Interpreter, Confidence factor, Dip angle, Dip azimuth, Missing, TVT, TST, TVT zone, TST zone, Observation number, Used by dep.conv., Used by geo mod, Zone log, Edited by user, Symbol, Locked to fault, FLOAT,GR_min_Ichron, FLOAT,GR_max_Ichron, Z_depth_T-1, TWT_Auto_T-1, isochron_auto, ischore, Vint_int, mid-point_Z]
# Index: []
#
# [0 rows x 30 columns]
